# %%
import pandas as pd
import numpy as np

# Display settings
pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", 150)

# %%
df=pd.read_csv(r"C:\Users\Login\OneDrive\Desktop\AniWise-Anime-Recommendation-System\data\raw\myanimelist_recommender_ready.csv")

# %%
df.head()
# Out:
#    mal_id                            title            title_english  \
# 0       1                     Cowboy Bebop             Cowboy Bebop
# 1       5  Cowboy Bebop: Tengoku no Tobira  Cowboy Bebop: The Movie
# 2       6                           Trigun                   Trigun
# 3       7               Witch Hunter Robin       Witch Hunter Robin
# 4       8                   Bouken Ou Beet   Beet the Vandel Buster
#
#                      title_japanese   type  episodes           status  score  \
# 0                         カウボーイビバップ     TV      26.0  Finished Airing   8.75
# 1                    カウボーイビバップ 天国の扉  Movie       1.0  Finished Airing   8.38
# 2                             トライガン     TV      26.0  Finished Airing   8.22
# 3  Witch Hunter ROBIN (ウイッチハンターロビン)     TV      26.0  Finished Airing   7.23
# 4                            冒険王ビィト     TV      52.0  Finished Airing   6.92
#
#      rank  popularity  members  favorites  \
# 0    46.0          42  1975882      86621
# ...

# %%
df.shape
# Out:
# (28707, 19)

# %%
df.columns
# Out:
# Index(['mal_id', 'title', 'title_english', 'title_japanese', 'type',
#        'episodes', 'status', 'score', 'rank', 'popularity', 'members',
#        'favorites', 'synopsis', 'genres', 'themes', 'demographics', 'studios',
#        'year', 'url'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 28707 entries, 0 to 28706
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   mal_id          28707 non-null  int64
#  1   title           28707 non-null  str
#  2   title_english   12343 non-null  str
#  3   title_japanese  28587 non-null  str
#  4   type            28634 non-null  str
#  5   episodes        27931 non-null  float64
#  6   status          28707 non-null  str
#  7   score           18598 non-null  float64
#  8   rank            21806 non-null  float64
#  9   popularity      28707 non-null  int64
#  10  members         28707 non-null  int64
#  11  favorites       28707 non-null  int64
#  12  synopsis        23629 non-null  str
#  13  genres          22800 non-null  str
#  14  themes          16917 non-null  str
#  15  demographics    10725 non-null  str
#  16  studios         17083 non-null  str
#  17  year            6192 non-null   float64
# ...

# %%
df.describe(include="all")
# Out:
#               mal_id               title title_english title_japanese   type  \
# count   28707.000000               28707         12343          28587  28634
# unique           NaN               28489         12034          27318      9
# top              NaN  Wan Xiang Zhi Wang       Promise        おしりたんてい     TV
# freq             NaN                   4             5              9   8358
# mean    33687.396419                 NaN           NaN            NaN    NaN
# std     19486.123233                 NaN           NaN            NaN    NaN
# min         1.000000                 NaN           NaN            NaN    NaN
# 25%     14990.000000                 NaN           NaN            NaN    NaN
# 50%     37736.000000                 NaN           NaN            NaN    NaN
# 75%     50047.000000                 NaN           NaN            NaN    NaN
# max     61852.000000                 NaN           NaN            NaN    NaN
#
# ...

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# year              22515
# demographics      17982
# title_english     16364
# themes            11790
# studios           11624
# score             10109
# rank               6901
# genres             5907
# synopsis           5078
# episodes            776
# title_japanese      120
# type                 73
# mal_id                0
# title                 0
# status                0
# members               0
# popularity            0
# favorites             0
# url                   0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(216)

# %% [markdown]
# ## Conclusion
#
# - Dataset contains 28,707 anime records with 19 features.
# - Data types are mostly appropriate.
# - Some metadata columns contain missing values, which is expected for real-world anime databases.
# - The dataset includes 216 duplicate records that will be handled during preprocessing.
# - Overall, the dataset is suitable for building a content-based anime recommendation system.
